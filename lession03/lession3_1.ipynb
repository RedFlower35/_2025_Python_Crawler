# %%
chinese = 93
english = 83
math = 74
total = chinese + english + math
print('total: ',total)
# Out:
# total:  250

# %%
print(123)
# Out:
# 123

# %%
orange = int(input('請輸入橘子的數量: '))
apple = int(input('請輸入蘋果的數量: '))

# %%
print(f'橘子有{orange}個 ,蘋果有{apple}個 ')
# Out:
# 蘋果有15個， 橘子有9個

# %%
age = 19
if (age >=18):
    print('滿18歲，可以考駕照了 !!')
else:
    print('未滿18歲，還不能考駕照 !!')
# Out:
# 滿18歲，可以考駕照了 !!

# %%
# 巢狀選擇
age = 10
if (age < 18):
    print('未滿18歲，青少年')
else:
    if (age < 40):
        print('青年')
    else:
        print('壯年')
# Out:
# 未滿18歲，青少年

# %%
age = 20
if (age<18):
    print('未滿18歲，青少年')
elif (age <= 40):
    print('青年')
else:
    print('壯年')
# Out:
# 青年

# %%
score = 85
if (score >=90):
    print('優')
elif(score >=80):
    print('甲')
elif(score >=70):
    print('乙')
elif(score >=60):
    print('丙')
else:
    print('丁')
# Out:
# 甲

# %%
score = 85
if (score >= 90):
    print('優')
elif (score >= 80 and score <90):
    print('甲')
elif (score >= 70 and score <80):
    print('乙')
elif (score >= 60 and score <70):
    print('丙')
else:
    print('丁')
# Out:
# 甲

# %%
score = 85
if (score >= 90):
    print('優')
elif (90 > score >= 80):
    print('甲')
elif (80 > score >= 70):
    print('乙')
elif (70 > score >= 60):
    print('丙')
else :
    print('丁')
# Out:
# 丁

# %%
total = 0
for i in range(1,11):
    total += i
    print('i:',i)
print('total: ',total)
# Out:
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# i: 10
# total:  55

# %%
import random

while (random.randint(1,10) != 5):
    print('這不是5')
print('這是5')
# Out:
# 這不是5
# 這不是5
# 這不是5
# 這不是5
# 這是5

# %%
import random
while True:
    randValue = random.randint(1,10)
    if (randValue == 5):
        print('這是5')
        break
    print('這不是5')
# Out:
# 這不是5
# 這不是5
# 這是5
