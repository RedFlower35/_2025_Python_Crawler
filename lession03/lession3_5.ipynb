# %%
nums = [1,2,3,4,5,6]
# 透過索引取值
print(nums[0])
print(nums[5])

#透過 slice取值
print(nums[0:3])
print(nums[:3])
print(nums[-3:-1])
print(nums[-3:])

nums.append(7)
print('after append: ',nums)
nums.insert(0,-1)
print('after insert: ',nums)
# Out:
# 1
# 6
# [1, 2, 3]
# [1, 2, 3]
# [4, 5]
# [4, 5, 6]
# after append:  [1, 2, 3, 4, 5, 6, 7]
# after insert:  [-1, 1, 2, 3, 4, 5, 6, 7]
